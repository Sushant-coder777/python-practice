# %%
# 1. Write a program to check whether a number is positive.

num=int(input("Enter number: "))
if num>0:
    print("Positive")

# %%
# 2. Write a program to check whether a number is negative.

num=int(input("Enter number: "))
if num<0:
    print("Negative")

# %%
# 3. Write a program to check whether a number is even.

num=int(input("Enter number: "))
if num%2==0:
    print("Even")

# %%
# 4. Write a program to check whether a number is odd.

num=int(input("Enter number: "))
if num%2!=0:
    print("Odd")

# %%
# 5. Write a program to check whether a number is greater than 100.

num=int(input("Enter number: "))
if num>100:
    print("Greater than 100")

# %%
# 6. Write a program to check whether a number is less than 50.

num=int(input("Enter number: "))
if num<50:
    print("Less than 50")

# %%
# 7. Write a program to check whether a number is divisible by 5.

num=int(input("Enter number: "))
if num%5==0:
    print("Divisible by 5")

# %%
# 8. Write a program to check whether a number is divisible by 10.

num=int(input("Enter number: "))
if num%10==0:
    print("Divisible by 10")

# %%
# 9. Write a program to check whether a person is eligible to vote.

age=int(input("Enter age: "))
if age>=18:
    print("Eligible to vote")

# %%
# 10. Write a program to check whether marks are greater than 40.

marks=int(input("Enter marks: "))
if marks>40:
    print("Marks greater than 40")

# %%
# 11. Write a program to check whether temperature is above 30 degrees.

temp=float(input("Enter temperature: "))
if temp>30:
    print("Above 30 degrees")

# %%
# 12. Write a program to check whether a number is zero.

num=int(input("Enter number: "))
if num==0:
    print("Zero")

# %%
# 13. Write a program to check whether salary is above 50000.

salary=float(input("Enter salary: "))
if salary>50000:
    print("Salary above 50000")

# %%
# 14. Write a program to check whether age is above 60.

age=int(input("Enter age: "))
if age>60:
    print("Above 60")

# %%
# 15. Write a program to check whether a number is multiple of 3.

num=int(input("Enter number: "))
if num%3==0:
    print("Multiple of 3")

# %%
# 16. Write a program to check whether a number is single digit.

num=int(input("Enter number: "))
if -9<=num<=9:
    print("Single digit")

# %%
# 17. Write a program to check whether balance is above 1000.

balance=float(input("Enter balance: "))
if balance>1000:
    print("Balance above 1000")

# %%
# 18. Write a program to check whether password length is greater than 8.

password=input("Enter password: ")
if len(password)>8:
    print("Length greater than 8")

# %%
# 19. Write a program to check whether attendance is above 75%.

attendance=float(input("Enter attendance: "))
if attendance>75:
    print("Attendance above 75%")

# %%
# 20. Write a program to check whether height is above 170 cm.

height=float(input("Enter height: "))
if height>170:
    print("Above 170 cm")

# %%
# 21. Write a program to check whether weight is above 70 kg.

weight=float(input("Enter weight: "))
if weight>70:
    print("Above 70 kg")

# %%
# 22. Write a program to check whether a number is less than 0.

num=int(input("Enter number: "))
if num<0:
    print("Less than 0")

# %%
# 23. Write a program to check whether discount is applicable above 1000.

amount=float(input("Enter amount: "))
if amount>1000:
    print("Discount applicable")

# %%
# 24. Write a program to check whether stock is available.

stock=int(input("Enter stock quantity: "))
if stock>0:
    print("Stock available")

# %%
# 25. Write a program to check whether exam score is above 90.

score=int(input("Enter score: "))
if score>90:
    print("Above 90")

# %%
# 26. Write a program to check whether a number is even or odd.

num=int(input("Enter number: "))
if num%2==0:
    print("Even")
else:
    print("Odd")

# %%
# 27. Write a program to check whether a number is positive or negative.

num=int(input("Enter number: "))
if num>=0:
    print("Positive")
else:
    print("Negative")

# %%
# 28. Write a program to check whether a person passed or failed.

marks=int(input("Enter marks: "))
if marks>=40:
    print("Pass")
else:
    print("Fail")

# %%
# 29. Write a program to compare two numbers and print the greater one.

a=int(input("Enter first: "))
b=int(input("Enter second: "))
if a>b:
    print(a,"is greater")
else:
    print(b,"is greater")

# %%
# 30. Write a program to check whether a year is leap year or not.

year=int(input("Enter year: "))
if (year%4==0 and year%100!=0) or (year%400==0):
    print("Leap Year")
else:
    print("Not Leap Year")

# %%
# 31. Write a program to check whether a number is divisible by 5 or not.

num=int(input("Enter number: "))
if num%5==0:
    print("Divisible")
else:
    print("Not Divisible")

# %%
# 32. Write a program to check whether age is eligible for driving license.

age=int(input("Enter age: "))
if age>=18:
    print("Eligible")
else:
    print("Not Eligible")

# %%
# 33. Write a program to check whether temperature is hot or normal.

temp=float(input("Enter temperature: "))
if temp>30:
    print("Hot")
else:
    print("Normal")

# %%
# 34. Write a program to check whether a number is greater than 50 or not.

num=int(input("Enter number: "))
if num>50:
    print("Greater than 50")
else:
    print("50 or less")

# %%
# 35. Write a program to check whether password is correct or not.

password=input("Enter password: ")
if password=="admin123":
    print("Correct")
else:
    print("Incorrect")

# %%
# 36. Write a program to check whether number is multiple of 7 or not.

num=int(input("Enter number: "))
if num%7==0:
    print("Multiple of 7")
else:
    print("Not Multiple")

# %%
# 37. Write a program to check whether student is adult or minor.

age=int(input("Enter age: "))
if age>=18:
    print("Adult")
else:
    print("Minor")

# %%
# 38. Write a program to check whether balance is sufficient or insufficient.

balance=float(input("Enter balance: "))
if balance>=500:
    print("Sufficient")
else:
    print("Insufficient")

# %%
# 39. Write a program to check whether character is vowel or consonant.

ch=input("Enter character: ")
if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")

# %%
# 40. Write a program to check whether marks are distinction or not.

marks=int(input("Enter marks: "))
if marks>=75:
    print("Distinction")
else:
    print("No Distinction")

# %%
# 41. Write a program to check whether number is divisible by 2.

num=int(input("Enter number: "))
if num%2==0:
    print("Divisible by 2")

# %%
# 42. Write a program to check whether attendance is sufficient.

attendance=float(input("Enter attendance: "))
if attendance>=75:
    print("Sufficient")
else:
    print("Insufficient")

# %%
# 43. Write a program to check whether number is three digit or not.

num=int(input("Enter number: "))
if 100<=abs(num)<=999:
    print("Three digit")
else:
    print("Not three digit")

# %%
# 43. seocnd method
num=int(input("Enter number: "))
if 100<=num<=999 or -100>=num>=-999:
    print("Three digit")
else:
    print("Not three digit")

# %%
# 44. Write a program to check whether salary is high or low.

salary=float(input("Enter salary: "))
if salary>50000:
    print("High")
else:
    print("Low")

# %%
# 45. Write a program to check whether order amount qualifies for free delivery.

amount=float(input("Enter order amount: "))
if amount>500:
    print("Free Delivery")
else:
    print("Delivery Charges Apply")

# %%
# 46. Write a program to check whether BMI is normal or not.

bmi=float(input("Enter BMI: "))
if 18.5<=bmi<=24.9:
    print("Normal")
else:
    print("Not Normal")

# %%
# 47. Write a program to check whether user is logged in or not.

status=input("Logged in? (yes/no): ")
if status=="yes":
    print("User logged in")
else:
    print("Not logged in")

# %%
# 48. Write a program to check whether number is greater than 1000.

num=int(input("Enter number: "))
if num>1000:
    print("Greater than 1000")

# %%
# 49. Write a program to check whether score is above average.

score=int(input("Enter score: "))
if score>60:
    print("Above average")
else:
    print("Below average")

# %%
# 50. Write a program to check whether age is senior citizen or not.

age=int(input("Enter age: "))
if age>=60:
    print("Senior Citizen")
else:
    print("Not Senior")

# %%
# 51. Write a program to check whether number is positive, negative, or zero.

num=int(input("Enter number: "))
if num>0:
    print("Positive")
elif num<0:
    print("Negative")
else:
    print("Zero")

# %%
# 52. Write a program to assign grade based on marks.

marks=int(input("Enter marks: "))
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
    print("Fail")

# %%
# 53. Write a program to categorize age into child, teenager, adult, senior.

age=int(input("Enter age: "))
if age<13:
    print("Child")
elif age<20:
    print("Teenager")
elif age<60:
    print("Adult")
else:
    print("Senior")

# %%
# 54. Write a program to find greatest among three numbers.

a=int(input("Enter first: "))
b=int(input("Enter second: "))
c=int(input("Enter third: "))
if a>=b and a>=c:
    print("First greatest")
elif b>=a and b>=c:
    print("Second greatest")
else:
    print("Third greatest")

# %%
# 55. Write a program to check leap year using multiple conditions.

year=int(input("Enter year: "))
if (year%4==0 and year%100!=0) or (year%400==0):
    print("Leap Year")
else:
    print("Not Leap Year")

# %%
# 56. Write a program to display day based on number (1-7).

day=int(input("Enter day number (1-7): "))
days=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
if 1<=day<=7:
    print(days[day-1])

# %%
# 57. Write a program to categorize temperature (Hot, Warm, Cool, Cold).

temp=float(input("Enter temperature: "))
if temp>=35:
    print("Hot")
elif temp>=25:
    print("Warm")
elif temp>=15:
    print("Cool")
else:
    print("Cold")

# %%
# 58. Write a program to check divisibility by 3 and 5.

num=int(input("Enter number: "))
if num%3==0 and num%5==0:
    print("Divisible by 3 and 5")

# %%
# 59. Write a program to categorize salary into low, medium, high.

salary=float(input("Enter salary: "))
if salary<30000:
    print("Low")
elif salary<70000:
    print("Medium")
else:
    print("High")

# %%
# 60. Write a program to categorize bank balance levels.

balance=float(input("Enter balance: "))
if balance<1000:
    print("Low Balance")
elif balance<5000:
    print("Moderate Balance")
else:
    print("High Balance")

# %%
# 61. Write a program to categorize speed levels.

speed=int(input("Enter speed: "))
if speed<40:
    print("Slow")
elif speed<80:
    print("Normal")
else:
    print("Fast")

# %%
# 62. Write a program to check number of digits (1, 2, 3, more).

num=input("Enter number: ")
if len(num)==1:
    print("1 digit")
elif len(num)==2:
    print("2 digit")
elif len(num)==3:
    print("3 digit")
else:
    print("More than 3 digits")

# %%
# 63. Write a program to categorize attendance percentage.

attendance=float(input("Enter attendance: "))
if attendance>=90:
    print("Excellent")
elif attendance>=75:
    print("Good")
else:
    print("Poor")

# %%
# 64. Write a program to categorize rainfall levels.

rain=float(input("Enter rainfall mm: "))
if rain<50:
    print("Low Rainfall")
elif rain<150:
    print("Moderate Rainfall")
else:
    print("Heavy Rainfall")

# %%
# 65. Write a program to calculate bonus based on salary slabs.

salary=float(input("Enter salary: "))
if salary>=50000:
    print("Bonus 10%")
elif salary>=30000:
    print("Bonus 5%")
else:
    print("No Bonus")

# %%
# 66. Write a program to categorize BMI levels.

bmi=float(input("Enter BMI: "))
if bmi<18.5:
    print("Underweight")
elif bmi<25:
    print("Normal")
elif bmi<30:
    print("Overweight")
else:
    print("Obese")

# %%
# 67. Write a program to determine ticket fare by age group.

age=int(input("Enter age: "))
if age<12:
    print("Fare 50")
elif age<60:
    print("Fare 100")
else:
    print("Fare 70")

# %%
# 68. Write a program to categorize electricity bill slabs.

units=int(input("Enter units: "))
if units<=100:
    print("Bill 5/unit")
elif units<=300:
    print("Bill 7/unit")
else:
    print("Bill 10/unit")

# %%
# 69. Write a program to determine season based on month number.

month=int(input("Enter month: "))
if month in [12,1,2]:
    print("Winter")
elif month in [3,4,5]:
    print("Summer")
elif month in [6,7,8]:
    print("Monsoon")
else:
    print("Autumn")

# %%
# 70. Write a program to categorize password strength.

password=input("Enter password: ")
if len(password)>=8 and any(c.isdigit() for c in password):
    print("Strong")
elif len(password)>=6:
    print("Medium")
else:
    print("Weak")
# Out:
# Medium

# %%
# 71. Write a program to compare two numbers (greater, smaller, equal).

a=int(input("Enter first: "))
b=int(input("Enter second: "))
if a>b:
    print("Greater:",a)
elif b>a:
    print("Greater:",b)
else:
    print("Equal")

# %%
# 72. Write a program to determine grade with multiple conditions.

marks=int(input("Enter marks: "))
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=60:
    print("Grade C")
else:
    print("Fail")

# %%
# 73. Write a program to categorize user experience level.

exp=int(input("Enter experience years: "))
if exp<2:
    print("Beginner")
elif exp<5:
    print("Intermediate")
else:
    print("Expert")

# %%
# 74. Write a program to determine discount percentage by purchase amount.

amount=float(input("Enter purchase amount: "))
if amount>5000:
    print("20% Discount")
elif amount>2000:
    print("10% Discount")
else:
    print("5% Discount")

# %%
# 75. Write a program to categorize product rating (Excellent, Good, Average, Poor).

rating=float(input("Enter rating (1-5): "))
if rating>=4.5:
    print("Excellent")
elif rating>=3.5:
    print("Good")
elif rating>=2.5:
    print("Average")
else:
    print("Poor")
