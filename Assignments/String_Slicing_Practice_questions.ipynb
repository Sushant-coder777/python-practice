# %%
# 1. Given text = "PythonProgramming", extract "Programming" using mixed indexing.

text = "PythonProgramming"
print(text[6:])

# %%
# 2. From text = "DataScience", print "Science" using one positive and one negative index.

text = "DataScience"
print(text[4:])

# %%
# 3. Given text = "ArtificialIntelligence", extract "Intelligence" using slicing.

text = "ArtificialIntelligence"
print(text[10:])

# %%
# 4. From text = "MachineLearning", print characters from index 2 to -3.

text = "MachineLearning"
print(text[2:-3])

# %%
# 5. Given text = "Developer", extract "elope" using mixed indexing.

text = "Developer"
print(text[3:-1])
# Out:
# elope

# %%
# 6. From text = "Notebook", print characters starting from index 1 and ending at -2.

text = "Notebook"
print(text[1:-2])

# %%
# 7. Given text = "Education", extract "ucat" using positive start and negative end index.

text = "Education"
print(text[2:-3])

# %%
# 8. From text = "Programming", print everything except the first two and last two characters.

text = "Programming"
print(text[2:-2])

# %%
# 9. Given text = "InterviewPreparation", extract "Preparation" using mixed slicing.

text = "InterviewPreparation"
print(text[9:])

# %%
# 10. From text = "Analysis", print characters from index -6 to 6.

text = "Analysis"
print(text[-6:6])

# %%
# 11. Given text = "ComputerVision", extract "Vision" using positive and negative indices.

text = "ComputerVision"
print(text[8:])

# %%
# 12. From text = "DeepLearning", print characters between index 1 and -1.

text = "DeepLearning"
print(text[1:-1])

# %%
# 13. Given text = "Algorithm", remove the first and last two characters using slicing.

text = "Algorithm"
print(text[2:-2])

# %%
# 14. From text = "Visualization", extract "lizat" using mixed indexing.

text = "Visualization"
print(text[5:-3])

# %%
# 15. Given text = "Understanding", print characters from -9 to -2.

text = "Understanding"
print(text[-9:-2])

# %%
# 16. From text = "Automation", extract "tom" using mixed indexing.

text = "Automation"
print(text[2:-5])

# %%
# 17. Given text = "Keyboard", print characters from index 2 to -3.

text = "Keyboard"
print(text[2:-3])

# %%
# 18. From text = "BeginnerFriendly", extract "Friendly" using slicing.

text = "BeginnerFriendly"
print(text[8:])

# %%
# 19. Given text = "DataAnalysis", print everything except the last three characters using mixed indexing.

text = "DataAnalysis"
print(text[:-3])

# %%
# 20. From text = "PythonDeveloper", extract "Developer" using a combination of positive and negative indices.

text = "PythonDeveloper"
print(text[6:])
